# %%
import os
import sys
import cv2
import shutil
import random
import pandas as pd
import numpy as np
from os.path import join
from tqdm import tqdm
import inspect

sys.path.append('../include')
from utils import get_frame_from_time, NameMapping, get_video_info

# %%
# Step 0: Load all necessary data
base_dir = 'C:\\Users\\Simon\\Data\\2024_SICS_Phase\\'
videos_folder_name = 'Videos 2'
videos = os.listdir(join(base_dir, videos_folder_name))
df = pd.read_csv(join(base_dir, '20240408_1529_cleaned_annotations.csv'))

print(f'Number of found videos: {len(videos)}')
print(f'Number of annotations: {len(df)}')

# Step 0.1: Create directories for the frames
if not os.path.exists(join(base_dir, 'groundTruth')):
    os.mkdir(join(base_dir, 'groundTruth'))
if not os.path.exists(join(base_dir, 'features')):
    os.mkdir(join(base_dir, 'features'))
if not os.path.exists(join(base_dir, 'videos')):
    os.mkdir(join(base_dir, 'videos'))
    
df.head()
# Out:
# Number of found videos: 72
# Number of annotations: 62
#    Video ID Annotator SR_bridle_suture_start SR_bridle_suture_stop  \
# 0   Video 5   Dr. SNP                    NaN                   NaN
# 1   Video 7   Dr. SNP                    NaN                   NaN
# 2   Video 8   Dr. SNP                    NaN                   NaN
# 3   Video 9   Dr. SNP                    NaN                   NaN
# 4  Video 10   Dr. SNP                    NaN                   NaN
#
#   peritomy_start peritomy_stop cautery_start cautery_stop  \
# 0           0:00          0:23          0:29         1:14
# 1            NaN           NaN           NaN          NaN
# 2            NaN           NaN          0:12         0:26
# 3           0:00          0:23           NaN          NaN
# 4           0:00          0:04           NaN          NaN
#
#   scleral_groove_start scleral_groove_stop  ... OVD_wash_start OVD_wash_stop  \
# 0                 1:19                1:26  ...          12:15         13:55
# 1                 0:00                0:32  ...          13:38         14:21
# 2                 0:36                0:47  ...          11:56         12:36
# 3                 0:31                0:48  ...          14:39         16:07
# 4                 0:10                0:13  ...           7:46          8:19
#
#   stromal_hydration_start stromal_hydration_stop tunnel_suture_start  \
# 0                   14:02                  14:32                 NaN
# 1                   14:30                  15:01                 NaN
# 2                   12:43                  13:21                 NaN
# 3                   16:28                  17:23                 NaN
# 4                    8:24                   9:18                 NaN
#
#   tunnel_suture_stop conjunctival_cautery_start conjunctival_cautery_stop  \
# 0                NaN                      15:08                     15:37
# 1                NaN                      15:15                     15:58
# 2                NaN                      13:33                     14:00
# 3                NaN                      20:06                     21:05
# 4                NaN                       9:28                      9:45
#
#   mapped_video_id  new_video_id
# 0     Video 5.mp4  case_100.mp4
# 1     Video 7.mp4  case_101.mp4
# 2     Video 8.mp4  case_102.mp4
# 3     Video 9.mp4  case_103.mp4
# 4    Video 10.mp4  case_104.mp4
#
# [5 rows x 44 columns]

# %%
# Step 1: Generate class mappings

#df = df.rename(columns={'capsulorrhexix_stop': 'capsulorrhexis_stop'})

def generate_mapping(dataframe):
    mapping = {"background": 0}
    mapping_count = 1
    for col_name in dataframe.columns[2:-2]:
        #print(f'Class: {col_name}')
        class_name = "_".join(col_name.split('_')[:-1])
        if mapping.get(class_name) is None:
            mapping[class_name] = mapping_count
            mapping_count += 1
    return mapping
        
mapping = generate_mapping(df)
print(mapping)

# Step 1.1: Write class mapping to file
with open(join(base_dir, 'class_mapping.txt'), 'w') as f:
    for key, value in mapping.items():
        f.write(f'{value}: {key}\n')
# Out:
# {'background': 0, 'SR_bridle_suture': 1, 'peritomy': 2, 'cautery': 3, 'scleral_groove': 4, 'incision': 5, 'tunnel': 6, 'sideport': 7, 'AB_injection_and_wash': 8, 'OVD_injection': 9, 'capsulorrhexis': 10, 'main_incision_entry': 11, 'hydroprocedure': 12, 'nucleus_prolapse': 13, 'nucleus_delivery': 14, 'cortical_wash': 15, 'OVD_IOL_insertion': 16, 'OVD_wash': 17, 'stromal_hydration': 18, 'tunnel_suture': 19, 'conjunctival_cautery': 20}

# %%
#[print(elm + ',') for elm in mapping.keys()]

# %%
# Step 2: Generate frame-wise annotations and write them to file 
 
def process_annotation(row, base_dir):
    duration, vid_len, fps = get_video_info(join(base_dir, videos_folder_name, row['mapped_video_id']))
    print(f"Working on video {row['Video ID']} with {int(vid_len)} frames and {fps} fps...")
    
    annotation = np.zeros(int(vid_len))
    for i in range(2, len(row) - 2, 2):
        #print(row[row.index[i]])
        start_frame = get_frame_from_time(row.iloc[i], fps=30)
        end_frame = get_frame_from_time(row.iloc[i+1], fps=30)
        if start_frame == None or end_frame == None:
            continue
        
        cur_class = "_".join(row.index[i].split('_')[:-1])
        annotation[start_frame:end_frame] = int(mapping[cur_class])
        #print(row.iloc[i], row.iloc[i+1], mapping[cur_class], np.count_nonzero(annotation == 0)/30.0)
    return annotation


# Generate frame-wise annotaitons for each annoated video
print(f'####### Processing {len(df)} annotations #######')
bg_perc = []
for i, row in df.iterrows():
    anno = process_annotation(row, base_dir)
    #print(len(anno), np.count_nonzero(anno))
    #print(anno[500:1000])
    
    # sanity check
    class_dict = dict(zip(*np.unique(anno, return_counts=True)))
    inv_class = {v: k for k, v in mapping.items()}
    class_occurence = {inv_class[k]: v/30.0 for k, v in class_dict.items()}
    background_count, total_count = class_occurence["background"], sum(class_occurence.values())
    bg_perc.append(background_count / total_count)
    print(f'Percentage of background: {background_count / total_count}, {class_occurence}')
    
    #convert and write to file
    anno_list = [inv_class[elm] for elm in anno.tolist()]
    with open(join(base_dir, 'groundTruth', f'{os.path.splitext(row["new_video_id"])[0]}.txt'), 'w') as f:
        f.write("\n".join(anno_list))
        pass
    
print(f'Average background percentage: {np.mean(bg_perc)}')
# Out:
# ####### Processing 62 annotations #######
# Working on video Video 5 with 28043 frames and 29.17378281668799 fps...
# Percentage of background: 0.21823627999857362, {'background': 204.0, 'peritomy': 23.0, 'cautery': 45.0, 'scleral_groove': 7.0, 'incision': 8.0, 'tunnel': 83.0, 'sideport': 12.0, 'AB_injection_and_wash': 35.0, 'OVD_injection': 9.0, 'capsulorrhexis': 95.0, 'main_incision_entry': 22.0, 'hydroprocedure': 9.0, 'nucleus_prolapse': 21.0, 'nucleus_delivery': 8.0, 'cortical_wash': 111.0, 'OVD_IOL_insertion': 86.0, 'OVD_wash': 100.0, 'stromal_hydration': 30.0, 'conjunctival_cautery': 26.766666666666666}
# Working on video Video 7 with 30599 frames and 29.997873776148097 fps...
# Percentage of background: 0.3431157880976502, {'background': 349.96666666666664, 'scleral_groove': 32.0, 'incision': 114.0, 'tunnel': 50.0, 'sideport': 10.0, 'AB_injection_and_wash': 16.0, 'OVD_injection': 5.0, 'capsulorrhexis': 85.0, 'main_incision_entry': 22.0, 'hydroprocedure': 28.0, 'nucleus_prolapse': 15.0, 'nucleus_delivery': 5.0, 'cortical_wash': 114.0, 'OVD_IOL_insertion': 57.0, 'OVD_wash': 43.0, 'stromal_hydration': 31.0, 'conjunctival_cautery': 43.0}
# Working on video Video 8 with 27030 frames and 29.997904572688046 fps...
# Percentage of background: 0.3895671476137625, {'background': 351.0, 'cautery': 14.0, 'scleral_groove': 11.0, 'incision': 11.0, 'tunnel': 59.0, 'sideport': 16.0, 'AB_injection_and_wash': 19.0, 'OVD_injection': 14.0, 'capsulorrhexis': 55.0, 'main_incision_entry': 31.0, 'hydroprocedure': 11.0, 'nucleus_prolapse': 23.0, 'nucleus_delivery': 14.0, 'cortical_wash': 93.0, 'OVD_IOL_insertion': 74.0, 'OVD_wash': 40.0, 'stromal_hydration': 38.0, 'conjunctival_cautery': 27.0}
# Working on video Video 9 with 38826 frames and 29.998175324740483 fps...
# Percentage of background: 0.30690774223458506, {'background': 397.2, 'peritomy': 23.0, 'scleral_groove': 17.0, 'incision': 29.0, 'tunnel': 32.0, 'sideport': 7.0, 'AB_injection_and_wash': 13.0, 'OVD_injection': 4.0, 'capsulorrhexis': 81.0, 'main_incision_entry': 4.0, 'hydroprocedure': 17.0, 'nucleus_prolapse': 13.0, 'nucleus_delivery': 5.0, 'cortical_wash': 415.0, 'OVD_IOL_insertion': 35.0, 'OVD_wash': 88.0, 'stromal_hydration': 55.0, 'conjunctival_cautery': 59.0}
# Working on video Video 10 with 18040 frames and 29.99823911490606 fps...
# Percentage of background: 0.2067627494456763, {'background': 124.33333333333333, 'peritomy': 4.0, 'scleral_groove': 3.0, 'incision': 10.0, 'tunnel': 71.0, 'sideport': 12.0, 'OVD_injection': 13.0, 'capsulorrhexis': 68.0, 'main_incision_entry': 30.0, 'hydroprocedure': 13.0, 'nucleus_prolapse': 17.0, 'nucleus_delivery': 8.0, 'cortical_wash': 74.0, 'OVD_IOL_insertion': 50.0, 'OVD_wash': 33.0, 'stromal_hydration': 54.0, 'conjunctival_cautery': 17.0}
# Working on video Video 11 with 12748 frames and 29.99755050036084 fps...
# Percentage of background: 0.39990586758707247, {'background': 169.93333333333334, 'peritomy': 24.0, 'incision': 11.0, 'tunnel': 27.0, 'capsulorrhexis': 43.0, 'hydroprocedure': 12.0, 'nucleus_prolapse': 15.0, 'nucleus_delivery': 16.0, 'cortical_wash': 34.0, 'OVD_IOL_insertion': 44.0, 'OVD_wash': 27.0, 'stromal_hydration': 2.0}
# Working on video Video 19 with 38669 frames and 29.998387228023947 fps...
# Percentage of background: 0.27849181514908583, {'background': 358.96666666666664, 'peritomy': 18.0, 'cautery': 22.0, 'scleral_groove': 39.0, 'incision': 36.0, 'tunnel': 50.0, 'sideport': 8.0, 'AB_injection_and_wash': 39.0, 'OVD_injection': 11.0, 'capsulorrhexis': 118.0, 'main_incision_entry': 25.0, 'hydroprocedure': 45.0, 'nucleus_prolapse': 25.0, 'nucleus_delivery': 18.0, 'cortical_wash': 247.0, 'OVD_IOL_insertion': 67.0, 'OVD_wash': 115.0, 'stromal_hydration': 23.0, 'conjunctival_cautery': 24.0}
# Working on video Video 20 with 37829 frames and 29.998137535589628 fps...
# Percentage of background: 0.24264453197282507, {'background': 305.96666666666664, 'peritomy': 32.0, 'cautery': 21.0, 'scleral_groove': 30.0, 'incision': 40.0, 'tunnel': 119.0, 'sideport': 7.0, 'AB_injection_and_wash': 22.0, 'OVD_injection': 7.0, 'capsulorrhexis': 190.0, 'main_incision_entry': 26.0, 'hydroprocedure': 41.0, 'nucleus_prolapse': 29.0, 'nucleus_delivery': 13.0, 'cortical_wash': 114.0, 'OVD_IOL_insertion': 89.0, 'OVD_wash': 74.0, 'stromal_hydration': 79.0, 'conjunctival_cautery': 22.0}
# Working on video Video 21 with 34044 frames and 29.99756519871447 fps...
# Percentage of background: 0.34614028903771593, {'background': 392.8, 'peritomy': 14.0, 'cautery': 38.0, 'scleral_groove': 3.0, 'incision': 10.0, 'tunnel': 81.0, 'sideport': 7.0, 'AB_injection_and_wash': 15.0, 'OVD_injection': 44.0, 'capsulorrhexis': 55.0, 'main_incision_entry': 88.0, 'hydroprocedure': 20.0, 'nucleus_prolapse': 31.0, 'nucleus_delivery': 40.0, 'cortical_wash': 113.0, 'OVD_IOL_insertion': 101.0, 'OVD_wash': 38.0, 'stromal_hydration': 23.0, 'conjunctival_cautery': 21.0}
# Working on video Video 22 with 33855 frames and 29.99879168680522 fps...
# Percentage of background: 0.23172352680549402, {'background': 261.5, 'peritomy': 12.0, 'cautery': 25.0, 'scleral_groove': 14.0, 'incision': 5.0, 'tunnel': 43.0, 'sideport': 42.0, 'AB_injection_and_wash': 12.0, 'OVD_injection': 10.0, 'capsulorrhexis': 59.0, 'main_incision_entry': 18.0, 'hydroprocedure': 9.0, 'nucleus_prolapse': 14.0, 'nucleus_delivery': 17.0, 'cortical_wash': 212.0, 'OVD_IOL_insertion': 47.0, 'OVD_wash': 275.0, 'stromal_hydration': 33.0, 'conjunctival_cautery': 20.0}
# Working on video Video 23 with 11287 frames and 29.996381303845695 fps...
# Percentage of background: 0.3700717639762558, {'background': 139.23333333333332, 'peritomy': 14.0, 'scleral_groove': 5.0, 'incision': 3.0, 'tunnel': 23.0, 'AB_injection_and_wash': 12.0, 'OVD_injection': 4.0, 'capsulorrhexis': 71.0, 'main_incision_entry': 7.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 2.0, 'cortical_wash': 28.0, 'OVD_IOL_insertion': 24.0, 'OVD_wash': 13.0, 'stromal_hydration': 12.0, 'conjunctival_cautery': 11.0}
# Working on video Video 24 with 50589 frames and 29.99901009572037 fps...
# Percentage of background: 0.6963766826780525, {'background': 1174.3, 'peritomy': 21.0, 'scleral_groove': 9.0, 'incision': 19.0, 'tunnel': 34.0, 'sideport': 8.0, 'OVD_injection': 10.0, 'capsulorrhexis': 59.0, 'main_incision_entry': 19.0, 'hydroprocedure': 20.0, 'nucleus_prolapse': 9.0, 'nucleus_delivery': 11.0, 'cortical_wash': 202.0, 'OVD_IOL_insertion': 48.0, 'OVD_wash': 19.0, 'stromal_hydration': 14.0, 'conjunctival_cautery': 10.0}
# Working on video Video 25 with 53976 frames and 30.000019988917256 fps...
# Percentage of background: 0.720987105380169, {'background': 1297.2, 'peritomy': 19.0, 'incision': 10.0, 'tunnel': 34.0, 'sideport': 6.0, 'AB_injection_and_wash': 23.0, 'OVD_injection': 11.0, 'capsulorrhexis': 56.0, 'main_incision_entry': 24.0, 'hydroprocedure': 20.0, 'nucleus_prolapse': 12.0, 'nucleus_delivery': 8.0, 'cortical_wash': 83.0, 'OVD_IOL_insertion': 51.0, 'OVD_wash': 28.0, 'stromal_hydration': 6.0, 'tunnel_suture': 103.0, 'conjunctival_cautery': 8.0}
# Working on video Video 26 with 20280 frames and 28.164048463693156 fps...
# Percentage of background: 0.3668639053254438, {'background': 248.0, 'peritomy': 20.0, 'scleral_groove': 3.0, 'incision': 16.0, 'tunnel': 29.0, 'sideport': 5.0, 'AB_injection_and_wash': 16.0, 'OVD_injection': 6.0, 'capsulorrhexis': 30.0, 'main_incision_entry': 16.0, 'hydroprocedure': 18.0, 'nucleus_prolapse': 56.0, 'nucleus_delivery': 6.0, 'cortical_wash': 85.0, 'OVD_IOL_insertion': 53.0, 'OVD_wash': 52.0, 'stromal_hydration': 17.0}
# Working on video Video 27 with 18354 frames and 29.9983247502637 fps...
# Percentage of background: 0.27917620137299776, {'background': 170.8, 'peritomy': 9.0, 'scleral_groove': 5.0, 'incision': 13.0, 'tunnel': 41.0, 'sideport': 4.0, 'AB_injection_and_wash': 17.0, 'OVD_injection': 7.0, 'capsulorrhexis': 39.0, 'main_incision_entry': 11.0, 'hydroprocedure': 59.0, 'nucleus_prolapse': 11.0, 'nucleus_delivery': 6.0, 'cortical_wash': 67.0, 'OVD_IOL_insertion': 65.0, 'OVD_wash': 33.0, 'stromal_hydration': 42.0, 'conjunctival_cautery': 12.0}
# Working on video Video 28 with 20126 frames and 28.204012319753605 fps...
# Percentage of background: 0.3217728311636689, {'background': 215.86666666666667, 'peritomy': 7.0, 'scleral_groove': 3.0, 'tunnel': 41.0, 'sideport': 5.0, 'AB_injection_and_wash': 26.0, 'OVD_injection': 6.0, 'capsulorrhexis': 40.0, 'main_incision_entry': 14.0, 'hydroprocedure': 14.0, 'nucleus_prolapse': 9.0, 'nucleus_delivery': 6.0, 'cortical_wash': 84.0, 'OVD_IOL_insertion': 120.0, 'OVD_wash': 33.0, 'stromal_hydration': 27.0, 'conjunctival_cautery': 20.0}
# Working on video Video 29 with 16903 frames and 30.0050416561743 fps...
# Percentage of background: 0.26876885759924274, {'background': 151.43333333333334, 'peritomy': 15.0, 'scleral_groove': 3.0, 'incision': 12.0, 'tunnel': 29.0, 'sideport': 7.0, 'AB_injection_and_wash': 12.0, 'OVD_injection': 4.0, 'capsulorrhexis': 31.0, 'main_incision_entry': 17.0, 'hydroprocedure': 25.0, 'nucleus_prolapse': 13.0, 'nucleus_delivery': 4.0, 'cortical_wash': 114.0, 'OVD_IOL_insertion': 45.0, 'OVD_wash': 35.0, 'stromal_hydration': 18.0, 'conjunctival_cautery': 28.0}
# Working on video Video 30 with 53184 frames and 29.530326487119737 fps...
# Percentage of background: 0.3631543321299639, {'background': 643.8, 'peritomy': 50.0, 'cautery': 47.0, 'scleral_groove': 25.0, 'incision': 36.0, 'tunnel': 244.0, 'sideport': 11.0, 'AB_injection_and_wash': 25.0, 'OVD_injection': 14.0, 'capsulorrhexis': 29.0, 'main_incision_entry': 23.0, 'hydroprocedure': 15.0, 'nucleus_prolapse': 51.0, 'nucleus_delivery': 64.0, 'cortical_wash': 165.0, 'OVD_IOL_insertion': 107.0, 'OVD_wash': 98.0, 'stromal_hydration': 76.0, 'conjunctival_cautery': 49.0}
# Working on video Video 31 with 27099 frames and 30.00322860372567 fps...
# Percentage of background: 0.3844791320712942, {'background': 347.3, 'peritomy': 12.0, 'cautery': 20.0, 'scleral_groove': 16.0, 'incision': 17.0, 'tunnel': 45.0, 'sideport': 7.0, 'AB_injection_and_wash': 14.0, 'OVD_injection': 11.0, 'capsulorrhexis': 58.0, 'main_incision_entry': 50.0, 'hydroprocedure': 12.0, 'nucleus_prolapse': 44.0, 'nucleus_delivery': 9.0, 'cortical_wash': 71.0, 'OVD_IOL_insertion': 70.0, 'OVD_wash': 45.0, 'stromal_hydration': 27.0, 'conjunctival_cautery': 28.0}
# Working on video Easy cataract 4 with 25231 frames and 29.998480847874553 fps...
# Percentage of background: 0.33771947207799935, {'background': 284.03333333333336, 'peritomy': 19.0, 'scleral_groove': 6.0, 'incision': 20.0, 'tunnel': 25.0, 'sideport': 8.0, 'AB_injection_and_wash': 16.0, 'OVD_injection': 5.0, 'capsulorrhexis': 50.0, 'main_incision_entry': 21.0, 'hydroprocedure': 43.0, 'nucleus_prolapse': 37.0, 'nucleus_delivery': 12.0, 'cortical_wash': 120.0, 'OVD_IOL_insertion': 67.0, 'OVD_wash': 50.0, 'stromal_hydration': 29.0, 'conjunctival_cautery': 29.0}
# Working on video Video N20 with 45033 frames and 29.99812536808867 fps...
# Percentage of background: 0.323829191925921, {'background': 486.1, 'peritomy': 83.0, 'cautery': 31.0, 'scleral_groove': 35.0, 'incision': 24.0, 'tunnel': 77.0, 'sideport': 22.0, 'AB_injection_and_wash': 22.0, 'OVD_injection': 9.0, 'capsulorrhexis': 163.0, 'main_incision_entry': 55.0, 'hydroprocedure': 28.0, 'nucleus_prolapse': 63.0, 'nucleus_delivery': 9.0, 'cortical_wash': 147.0, 'OVD_IOL_insertion': 129.0, 'OVD_wash': 55.0, 'stromal_hydration': 29.0, 'conjunctival_cautery': 34.0}
# Working on video Video N19 with 19828 frames and 29.998107720861622 fps...
# Percentage of background: 0.3373007867661892, {'background': 222.93333333333334, 'peritomy': 15.0, 'scleral_groove': 20.0, 'incision': 9.0, 'tunnel': 40.0, 'OVD_injection': 3.0, 'capsulorrhexis': 30.0, 'main_incision_entry': 5.0, 'hydroprocedure': 10.0, 'nucleus_prolapse': 29.0, 'nucleus_delivery': 8.0, 'cortical_wash': 203.0, 'OVD_IOL_insertion': 25.0, 'OVD_wash': 20.0, 'conjunctival_cautery': 21.0}
# Working on video video N18 with 18030 frames and 29.99965093549288 fps...
# Percentage of background: 0.26955074875207985, {'background': 162.0, 'scleral_groove': 13.0, 'incision': 8.0, 'tunnel': 58.0, 'AB_injection_and_wash': 30.0, 'OVD_injection': 5.0, 'capsulorrhexis': 83.0, 'main_incision_entry': 5.0, 'hydroprocedure': 6.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 29.0, 'cortical_wash': 41.0, 'OVD_IOL_insertion': 89.0, 'OVD_wash': 35.0, 'stromal_hydration': 12.0, 'conjunctival_cautery': 15.0}
# Working on video Video 15 with 19859 frames and 29.999394846689466 fps...
# Percentage of background: 0.3157258673649227, {'background': 209.0, 'cautery': 64.0, 'scleral_groove': 5.0, 'incision': 9.0, 'tunnel': 67.0, 'sideport': 6.0, 'AB_injection_and_wash': 29.0, 'OVD_injection': 7.0, 'capsulorrhexis': 149.0, 'main_incision_entry': 26.0, 'hydroprocedure': 52.0, 'nucleus_prolapse': 17.0, 'nucleus_delivery': 21.966666666666665}
# Working on video Video N25 with 10858 frames and 29.998200470858393 fps...
# Percentage of background: 0.5551666973659974, {'background': 200.93333333333334, 'sideport': 4.0, 'OVD_injection': 4.0, 'capsulorrhexis': 18.0, 'main_incision_entry': 8.0, 'hydroprocedure': 6.0, 'nucleus_prolapse': 5.0, 'nucleus_delivery': 6.0, 'cortical_wash': 30.0, 'OVD_IOL_insertion': 27.0, 'OVD_wash': 34.0, 'stromal_hydration': 13.0, 'conjunctival_cautery': 6.0}
# Working on video Video N26 with 14458 frames and 29.99777801268937 fps...
# Percentage of background: 0.4522063909254392, {'background': 217.93333333333334, 'peritomy': 24.0, 'scleral_groove': 4.0, 'incision': 2.0, 'tunnel': 38.0, 'sideport': 3.0, 'OVD_injection': 5.0, 'capsulorrhexis': 24.0, 'main_incision_entry': 10.0, 'hydroprocedure': 10.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 10.0, 'cortical_wash': 53.0, 'OVD_IOL_insertion': 25.0, 'OVD_wash': 12.0, 'stromal_hydration': 22.0, 'conjunctival_cautery': 12.0}
# Working on video Video N27 with 10834 frames and 29.99721736628975 fps...
# Percentage of background: 0.4628022890899022, {'background': 167.13333333333333, 'peritomy': 17.0, 'scleral_groove': 3.0, 'incision': 3.0, 'tunnel': 25.0, 'sideport': 3.0, 'OVD_injection': 4.0, 'capsulorrhexis': 21.0, 'main_incision_entry': 6.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 4.0, 'nucleus_delivery': 6.0, 'cortical_wash': 30.0, 'OVD_IOL_insertion': 23.0, 'OVD_wash': 19.0, 'stromal_hydration': 15.0, 'conjunctival_cautery': 8.0}
# Working on video Video N28 with 16228 frames and 29.99779876420554 fps...
# Percentage of background: 0.4010352477199901, {'background': 216.93333333333334, 'peritomy': 13.0, 'scleral_groove': 7.0, 'incision': 2.0, 'tunnel': 56.0, 'sideport': 3.0, 'OVD_injection': 9.0, 'capsulorrhexis': 25.0, 'main_incision_entry': 18.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 7.0, 'nucleus_delivery': 5.0, 'cortical_wash': 96.0, 'OVD_IOL_insertion': 30.0, 'OVD_wash': 16.0, 'stromal_hydration': 14.0, 'conjunctival_cautery': 16.0}
# Working on video Video N29 with 10858 frames and 29.996461867096468 fps...
# Percentage of background: 0.4695155645606926, {'background': 169.93333333333334, 'tunnel': 27.0, 'sideport': 3.0, 'OVD_injection': 5.0, 'capsulorrhexis': 14.0, 'main_incision_entry': 8.0, 'hydroprocedure': 6.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 6.0, 'cortical_wash': 43.0, 'OVD_IOL_insertion': 27.0, 'OVD_wash': 20.0, 'stromal_hydration': 9.0, 'conjunctival_cautery': 14.0}
# Working on video Video N30 with 16258 frames and 29.99774753187003 fps...
# Percentage of background: 0.5700578176897527, {'background': 308.93333333333334, 'peritomy': 10.0, 'scleral_groove': 6.0, 'incision': 2.0, 'tunnel': 22.0, 'sideport': 2.0, 'AB_injection_and_wash': 11.0, 'OVD_injection': 6.0, 'capsulorrhexis': 17.0, 'main_incision_entry': 4.0, 'hydroprocedure': 10.0, 'nucleus_prolapse': 5.0, 'nucleus_delivery': 7.0, 'cortical_wash': 37.0, 'OVD_IOL_insertion': 42.0, 'OVD_wash': 26.0, 'stromal_hydration': 15.0, 'conjunctival_cautery': 11.0}
# Working on video Video N39 with 25229 frames and 29.998347694493344 fps...
# Percentage of background: 0.3067501684569344, {'background': 257.96666666666664, 'scleral_groove': 25.0, 'incision': 31.0, 'tunnel': 31.0, 'sideport': 6.0, 'AB_injection_and_wash': 18.0, 'OVD_injection': 4.0, 'capsulorrhexis': 31.0, 'main_incision_entry': 22.0, 'hydroprocedure': 13.0, 'nucleus_prolapse': 30.0, 'nucleus_delivery': 5.0, 'cortical_wash': 215.0, 'OVD_IOL_insertion': 54.0, 'OVD_wash': 65.0, 'stromal_hydration': 12.0, 'conjunctival_cautery': 21.0}
# Working on video Video N40  with 16253 frames and 29.99781136834652 fps...
# Percentage of background: 0.37426936565557134, {'background': 202.76666666666668, 'scleral_groove': 9.0, 'incision': 7.0, 'tunnel': 18.0, 'sideport': 7.0, 'OVD_injection': 3.0, 'capsulorrhexis': 21.0, 'main_incision_entry': 12.0, 'hydroprocedure': 4.0, 'nucleus_prolapse': 7.0, 'nucleus_delivery': 5.0, 'cortical_wash': 44.0, 'OVD_IOL_insertion': 89.0, 'OVD_wash': 43.0, 'stromal_hydration': 10.0, 'conjunctival_cautery': 60.0}
# Working on video Video N41 with 21129 frames and 29.970297703141405 fps...
# Percentage of background: 0.35680817833309675, {'background': 251.3, 'peritomy': 12.0, 'scleral_groove': 7.0, 'incision': 10.0, 'tunnel': 28.0, 'sideport': 4.0, 'OVD_injection': 5.0, 'capsulorrhexis': 31.0, 'main_incision_entry': 13.0, 'hydroprocedure': 8.0, 'nucleus_prolapse': 7.0, 'nucleus_delivery': 6.0, 'cortical_wash': 86.0, 'OVD_IOL_insertion': 75.0, 'OVD_wash': 94.0, 'stromal_hydration': 48.0, 'conjunctival_cautery': 19.0}
# Working on video Video N42 with 19830 frames and 29.99968262028691 fps...
# Percentage of background: 0.394856278366112, {'background': 261.0, 'peritomy': 11.0, 'scleral_groove': 11.0, 'incision': 12.0, 'tunnel': 32.0, 'sideport': 5.0, 'OVD_injection': 3.0, 'capsulorrhexis': 31.0, 'main_incision_entry': 15.0, 'hydroprocedure': 24.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 5.0, 'cortical_wash': 76.0, 'OVD_IOL_insertion': 57.0, 'OVD_wash': 51.0, 'stromal_hydration': 32.0, 'conjunctival_cautery': 25.0}
# Working on video Video N48 with 28827 frames and 29.99812562570107 fps...
# Percentage of background: 0.42345717556457485, {'background': 406.9, 'peritomy': 24.0, 'scleral_groove': 4.0, 'incision': 4.0, 'tunnel': 56.0, 'sideport': 8.0, 'OVD_injection': 7.0, 'capsulorrhexis': 105.0, 'main_incision_entry': 20.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 9.0, 'cortical_wash': 86.0, 'OVD_IOL_insertion': 52.0, 'OVD_wash': 26.0, 'stromal_hydration': 19.0, 'tunnel_suture': 104.0, 'conjunctival_cautery': 15.0}
# Working on video Video N49 with 23787 frames and 29.998182026630854 fps...
# Percentage of background: 0.4715600958506747, {'background': 373.9, 'peritomy': 17.0, 'scleral_groove': 7.0, 'incision': 11.0, 'tunnel': 27.0, 'sideport': 29.0, 'OVD_injection': 6.0, 'capsulorrhexis': 72.0, 'main_incision_entry': 21.0, 'hydroprocedure': 29.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 9.0, 'cortical_wash': 67.0, 'OVD_IOL_insertion': 45.0, 'OVD_wash': 36.0, 'stromal_hydration': 20.0, 'conjunctival_cautery': 13.0}
# Working on video Video N50 with 27000 frames and 29.996770244518018 fps...
# Percentage of background: 0.33666666666666667, {'background': 303.0, 'peritomy': 15.0, 'scleral_groove': 7.0, 'incision': 23.0, 'tunnel': 41.0, 'sideport': 5.0, 'OVD_injection': 6.0, 'capsulorrhexis': 47.0, 'main_incision_entry': 26.0, 'hydroprocedure': 26.0, 'nucleus_prolapse': 37.0, 'nucleus_delivery': 13.0, 'cortical_wash': 205.0, 'OVD_IOL_insertion': 49.0, 'OVD_wash': 48.0, 'stromal_hydration': 19.0, 'conjunctival_cautery': 30.0}
# Working on video Video N38 with 27028 frames and 29.998312423424274 fps...
# Percentage of background: 0.3806422968773124, {'background': 342.93333333333334, 'peritomy': 9.0, 'scleral_groove': 5.0, 'incision': 12.0, 'tunnel': 19.0, 'sideport': 8.0, 'OVD_injection': 6.0, 'capsulorrhexis': 62.0, 'main_incision_entry': 13.0, 'hydroprocedure': 12.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 15.0, 'cortical_wash': 126.0, 'OVD_IOL_insertion': 38.0, 'OVD_wash': 184.0, 'stromal_hydration': 19.0, 'conjunctival_cautery': 22.0}
# Working on video Video N46 with 18058 frames and 29.9977729098211 fps...
# Percentage of background: 0.3520877173551888, {'background': 211.93333333333334, 'peritomy': 22.0, 'scleral_groove': 9.0, 'incision': 12.0, 'tunnel': 65.0, 'sideport': 5.0, 'OVD_injection': 5.0, 'capsulorrhexis': 31.0, 'main_incision_entry': 20.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 9.0, 'nucleus_delivery': 9.0, 'cortical_wash': 84.0, 'OVD_IOL_insertion': 58.0, 'OVD_wash': 25.0, 'stromal_hydration': 18.0, 'conjunctival_cautery': 11.0}
# Working on video Video 56 with 10858 frames and 29.996296296296297 fps...
# Percentage of background: 0.43636028734573584, {'background': 157.93333333333334, 'peritomy': 13.0, 'scleral_groove': 6.0, 'incision': 7.0, 'tunnel': 17.0, 'capsulorrhexis': 21.0, 'main_incision_entry': 16.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 5.0, 'cortical_wash': 16.0, 'OVD_IOL_insertion': 26.0, 'OVD_wash': 43.0, 'stromal_hydration': 5.0, 'conjunctival_cautery': 14.0}
# Working on video Video 57 with 14458 frames and 29.99790236895506 fps...
# Percentage of background: 0.43768156038179556, {'background': 210.93333333333334, 'tunnel': 18.0, 'OVD_injection': 6.0, 'capsulorrhexis': 40.0, 'main_incision_entry': 86.0, 'hydroprocedure': 5.0, 'nucleus_prolapse': 6.0, 'nucleus_delivery': 5.0, 'cortical_wash': 44.0, 'OVD_IOL_insertion': 25.0, 'OVD_wash': 7.0, 'stromal_hydration': 4.0, 'conjunctival_cautery': 25.0}
# Working on video Video 58 with 22155 frames and 28.365336897574952 fps...
# Percentage of background: 0.6371022342586323, {'background': 470.5, 'peritomy': 1.0, 'scleral_groove': 5.0, 'incision': 5.0, 'tunnel': 15.0, 'AB_injection_and_wash': 11.0, 'OVD_injection': 2.0, 'capsulorrhexis': 19.0, 'main_incision_entry': 3.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 5.0, 'nucleus_delivery': 6.0, 'cortical_wash': 74.0, 'OVD_IOL_insertion': 23.0, 'OVD_wash': 17.0, 'stromal_hydration': 61.0, 'conjunctival_cautery': 14.0}
# Working on video Video 59 with 10858 frames and 29.998200470858393 fps...
# Percentage of background: 0.31479093755756127, {'background': 113.93333333333334, 'peritomy': 9.0, 'scleral_groove': 7.0, 'incision': 5.0, 'tunnel': 17.0, 'capsulorrhexis': 21.0, 'main_incision_entry': 19.0, 'hydroprocedure': 4.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 6.0, 'cortical_wash': 93.0, 'OVD_IOL_insertion': 22.0, 'OVD_wash': 14.0, 'stromal_hydration': 5.0, 'conjunctival_cautery': 18.0}
# Working on video Video 60 with 14450 frames and 30.0263635891847 fps...
# Percentage of background: 0.2878892733564014, {'background': 138.66666666666666, 'peritomy': 19.0, 'scleral_groove': 14.0, 'incision': 14.0, 'tunnel': 43.0, 'sideport': 3.0, 'AB_injection_and_wash': 10.0, 'OVD_injection': 8.0, 'capsulorrhexis': 29.0, 'main_incision_entry': 9.0, 'hydroprocedure': 6.0, 'nucleus_prolapse': 36.0, 'nucleus_delivery': 2.0, 'cortical_wash': 61.0, 'OVD_IOL_insertion': 39.0, 'OVD_wash': 21.0, 'stromal_hydration': 11.0, 'conjunctival_cautery': 18.0}
# Working on video Video 12 with 16227 frames and 29.99639339176297 fps...
# Percentage of background: 0.3732667775929007, {'background': 201.9, 'peritomy': 13.0, 'scleral_groove': 2.0, 'incision': 9.0, 'tunnel': 20.0, 'AB_injection_and_wash': 9.0, 'OVD_injection': 3.0, 'capsulorrhexis': 47.0, 'main_incision_entry': 7.0, 'hydroprocedure': 13.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 3.0, 'cortical_wash': 136.0, 'OVD_IOL_insertion': 28.0, 'OVD_wash': 20.0, 'stromal_hydration': 16.0, 'conjunctival_cautery': 5.0}
# Working on video Video 13 with 25250 frames and 29.99855201299865 fps...
# Percentage of background: 0.3596039603960396, {'background': 302.6666666666667, 'peritomy': 8.0, 'scleral_groove': 8.0, 'incision': 26.0, 'tunnel': 36.0, 'sideport': 11.0, 'AB_injection_and_wash': 13.0, 'OVD_injection': 7.0, 'capsulorrhexis': 89.0, 'main_incision_entry': 10.0, 'hydroprocedure': 22.0, 'nucleus_prolapse': 11.0, 'nucleus_delivery': 3.0, 'cortical_wash': 116.0, 'OVD_IOL_insertion': 47.0, 'OVD_wash': 80.0, 'stromal_hydration': 10.0, 'conjunctival_cautery': 42.0}
# Working on video video n10 with 54031 frames and 29.9987082009549 fps...
# Percentage of background: 0.17880476023023822, {'background': 322.03333333333336, 'peritomy': 69.0, 'cautery': 26.0, 'scleral_groove': 41.0, 'incision': 144.0, 'tunnel': 197.0, 'sideport': 10.0, 'AB_injection_and_wash': 34.0, 'OVD_injection': 9.0, 'capsulorrhexis': 98.0, 'main_incision_entry': 27.0, 'hydroprocedure': 25.0, 'nucleus_prolapse': 32.0, 'nucleus_delivery': 9.0, 'cortical_wash': 280.0, 'OVD_IOL_insertion': 86.0, 'OVD_wash': 74.0, 'stromal_hydration': 8.0, 'tunnel_suture': 287.0, 'conjunctival_cautery': 23.0}
# Working on video video n11 with 64834 frames and 29.998897093151715 fps...
# Percentage of background: 0.20597217509331525, {'background': 445.1333333333333, 'peritomy': 50.0, 'cautery': 20.0, 'scleral_groove': 71.0, 'incision': 40.0, 'tunnel': 79.0, 'sideport': 8.0, 'AB_injection_and_wash': 34.0, 'OVD_injection': 15.0, 'capsulorrhexis': 81.0, 'main_incision_entry': 29.0, 'hydroprocedure': 37.0, 'nucleus_prolapse': 28.0, 'nucleus_delivery': 40.0, 'cortical_wash': 194.0, 'OVD_IOL_insertion': 74.0, 'OVD_wash': 111.0, 'stromal_hydration': 199.0, 'tunnel_suture': 568.0, 'conjunctival_cautery': 38.0}
# Working on video video n14 with 33942 frames and 29.997865111794685 fps...
# Percentage of background: 0.2372282128336574, {'background': 268.4, 'scleral_groove': 3.0, 'incision': 52.0, 'tunnel': 67.0, 'sideport': 8.0, 'AB_injection_and_wash': 34.0, 'OVD_injection': 24.0, 'capsulorrhexis': 53.0, 'main_incision_entry': 38.0, 'hydroprocedure': 19.0, 'nucleus_prolapse': 67.0, 'nucleus_delivery': 9.0, 'cortical_wash': 103.0, 'OVD_IOL_insertion': 215.0, 'OVD_wash': 66.0, 'stromal_hydration': 81.0, 'conjunctival_cautery': 24.0}
# Working on video video n23 with 14458 frames and 30.000451899636822 fps...
# Percentage of background: 0.5497302531470466, {'background': 264.93333333333334, 'peritomy': 19.0, 'scleral_groove': 6.0, 'incision': 7.0, 'tunnel': 32.0, 'sideport': 4.0, 'OVD_injection': 4.0, 'capsulorrhexis': 17.0, 'main_incision_entry': 6.0, 'hydroprocedure': 8.0, 'nucleus_prolapse': 6.0, 'nucleus_delivery': 7.0, 'cortical_wash': 28.0, 'OVD_IOL_insertion': 22.0, 'OVD_wash': 21.0, 'stromal_hydration': 18.0, 'conjunctival_cautery': 12.0}
# Working on video video n24 with 19863 frames and 29.998963464773645 fps...
# Percentage of background: 0.3701857725419121, {'background': 245.1, 'peritomy': 9.0, 'scleral_groove': 2.0, 'incision': 9.0, 'tunnel': 21.0, 'sideport': 3.0, 'OVD_injection': 4.0, 'capsulorrhexis': 25.0, 'main_incision_entry': 6.0, 'hydroprocedure': 6.0, 'nucleus_prolapse': 7.0, 'nucleus_delivery': 8.0, 'cortical_wash': 231.0, 'OVD_IOL_insertion': 29.0, 'OVD_wash': 38.0, 'stromal_hydration': 11.0, 'conjunctival_cautery': 8.0}
# Working on video video n31 with 16258 frames and 29.998189888444042 fps...
# Percentage of background: 0.39660474843154137, {'background': 214.93333333333334, 'scleral_groove': 3.0, 'incision': 9.0, 'tunnel': 29.0, 'sideport': 9.0, 'AB_injection_and_wash': 13.0, 'OVD_injection': 4.0, 'capsulorrhexis': 23.0, 'main_incision_entry': 30.0, 'hydroprocedure': 8.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 4.0, 'cortical_wash': 98.0, 'OVD_IOL_insertion': 41.0, 'OVD_wash': 15.0, 'stromal_hydration': 3.0, 'conjunctival_cautery': 28.0}
# Working on video video n32 with 18058 frames and 29.998320524288506 fps...
# Percentage of background: 0.44844390297928893, {'background': 269.93333333333334, 'peritomy': 9.0, 'scleral_groove': 2.0, 'incision': 8.0, 'tunnel': 19.0, 'sideport': 18.0, 'OVD_injection': 3.0, 'capsulorrhexis': 21.0, 'main_incision_entry': 11.0, 'hydroprocedure': 7.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 4.0, 'cortical_wash': 142.0, 'OVD_IOL_insertion': 32.0, 'OVD_wash': 32.0, 'stromal_hydration': 6.0, 'conjunctival_cautery': 10.0}
# Working on video video n33 with 25228 frames and 29.998263292877482 fps...
# Percentage of background: 0.39947677184081176, {'background': 335.93333333333334, 'peritomy': 14.0, 'scleral_groove': 5.0, 'incision': 6.0, 'tunnel': 39.0, 'sideport': 7.0, 'OVD_injection': 5.0, 'capsulorrhexis': 42.0, 'main_incision_entry': 20.0, 'hydroprocedure': 15.0, 'nucleus_prolapse': 7.0, 'nucleus_delivery': 7.0, 'cortical_wash': 173.0, 'OVD_IOL_insertion': 61.0, 'OVD_wash': 63.0, 'stromal_hydration': 25.0, 'conjunctival_cautery': 16.0}
# Working on video video n34 with 25232 frames and 29.9977457655905 fps...
# Percentage of background: 0.34250158528852254, {'background': 288.06666666666666, 'peritomy': 11.0, 'scleral_groove': 2.0, 'incision': 3.0, 'tunnel': 37.0, 'sideport': 5.0, 'OVD_injection': 8.0, 'capsulorrhexis': 58.0, 'main_incision_entry': 14.0, 'hydroprocedure': 30.0, 'nucleus_prolapse': 14.0, 'nucleus_delivery': 15.0, 'cortical_wash': 78.0, 'OVD_IOL_insertion': 34.0, 'OVD_wash': 57.0, 'stromal_hydration': 39.0, 'tunnel_suture': 125.0, 'conjunctival_cautery': 23.0}
# Working on video video n43 with 21627 frames and 29.996545675235275 fps...
# Percentage of background: 0.42433069773893745, {'background': 305.9, 'peritomy': 8.0, 'scleral_groove': 3.0, 'incision': 30.0, 'tunnel': 52.0, 'sideport': 4.0, 'AB_injection_and_wash': 18.0, 'OVD_injection': 4.0, 'capsulorrhexis': 26.0, 'main_incision_entry': 9.0, 'hydroprocedure': 11.0, 'nucleus_prolapse': 5.0, 'nucleus_delivery': 6.0, 'cortical_wash': 103.0, 'OVD_IOL_insertion': 53.0, 'OVD_wash': 57.0, 'stromal_hydration': 15.0, 'conjunctival_cautery': 11.0}
# Working on video video n44 with 20458 frames and 29.998297819979083 fps...
# Percentage of background: 0.373839084954541, {'background': 254.93333333333334, 'peritomy': 25.0, 'scleral_groove': 4.0, 'incision': 6.0, 'tunnel': 51.0, 'sideport': 19.0, 'AB_injection_and_wash': 25.0, 'OVD_injection': 10.0, 'capsulorrhexis': 49.0, 'main_incision_entry': 25.0, 'hydroprocedure': 22.0, 'nucleus_prolapse': 14.0, 'nucleus_delivery': 9.0, 'cortical_wash': 57.0, 'OVD_IOL_insertion': 55.0, 'OVD_wash': 22.0, 'stromal_hydration': 24.0, 'conjunctival_cautery': 10.0}
# Working on video video n45 with 18057 frames and 29.997007776793094 fps...
# Percentage of background: 0.40853962452234593, {'background': 245.9, 'peritomy': 14.0, 'scleral_groove': 4.0, 'incision': 3.0, 'tunnel': 35.0, 'sideport': 4.0, 'OVD_injection': 5.0, 'capsulorrhexis': 32.0, 'main_incision_entry': 13.0, 'hydroprocedure': 8.0, 'nucleus_prolapse': 10.0, 'nucleus_delivery': 13.0, 'cortical_wash': 88.0, 'OVD_IOL_insertion': 40.0, 'OVD_wash': 23.0, 'stromal_hydration': 33.0, 'conjunctival_cautery': 31.0}
# Working on video video 52 with 9031 frames and 29.996253799291242 fps...
# Percentage of background: 0.4817849629055476, {'background': 145.03333333333333, 'peritomy': 7.0, 'scleral_groove': 5.0, 'incision': 5.0, 'tunnel': 18.0, 'OVD_injection': 6.0, 'capsulorrhexis': 19.0, 'main_incision_entry': 6.0, 'hydroprocedure': 5.0, 'nucleus_prolapse': 8.0, 'nucleus_delivery': 4.0, 'cortical_wash': 35.0, 'OVD_IOL_insertion': 15.0, 'OVD_wash': 7.0, 'stromal_hydration': 7.0, 'conjunctival_cautery': 9.0}
# Working on video video 53 with 10832 frames and 29.99757094204843 fps...
# Percentage of background: 0.46824224519940916, {'background': 169.06666666666666, 'peritomy': 6.0, 'scleral_groove': 4.0, 'incision': 4.0, 'tunnel': 18.0, 'sideport': 3.0, 'OVD_injection': 3.0, 'capsulorrhexis': 18.0, 'main_incision_entry': 3.0, 'hydroprocedure': 5.0, 'nucleus_prolapse': 11.0, 'nucleus_delivery': 5.0, 'cortical_wash': 29.0, 'OVD_IOL_insertion': 22.0, 'OVD_wash': 37.0, 'stromal_hydration': 19.0, 'conjunctival_cautery': 5.0}
# Working on video video 54 with 17342 frames and 29.999986174597552 fps...
# Percentage of background: 0.425671779494868, {'background': 246.06666666666666, 'peritomy': 6.0, 'scleral_groove': 3.0, 'incision': 4.0, 'tunnel': 21.0, 'AB_injection_and_wash': 16.0, 'OVD_injection': 3.0, 'capsulorrhexis': 91.0, 'main_incision_entry': 2.0, 'nucleus_prolapse': 16.0, 'nucleus_delivery': 6.0, 'cortical_wash': 44.0, 'OVD_IOL_insertion': 46.0, 'OVD_wash': 40.0, 'stromal_hydration': 13.0, 'conjunctival_cautery': 21.0}
# Working on video video 55 with 47974 frames and 29.59124475303849 fps...
# Percentage of background: 0.4828448743069163, {'background': 772.1333333333333, 'SR_bridle_suture': 14.0, 'peritomy': 14.0, 'cautery': 18.0, 'incision': 4.0, 'tunnel': 31.0, 'sideport': 2.0, 'AB_injection_and_wash': 18.0, 'OVD_injection': 3.0, 'capsulorrhexis': 102.0, 'main_incision_entry': 7.0, 'hydroprocedure': 10.0, 'nucleus_prolapse': 31.0, 'nucleus_delivery': 6.0, 'cortical_wash': 19.0, 'OVD_IOL_insertion': 92.0, 'OVD_wash': 20.0, 'stromal_hydration': 7.0, 'tunnel_suture': 416.0, 'conjunctival_cautery': 13.0}
# Average background percentage: 0.3817427588613308

# %%
# Step 3: Rename files to unified format
# In some cases this should be executed first, also think about rescaling first / or after
# See downscale script in script folder

CHANGE_FILES = False # Set to True if you want to rename files

for i, row in tqdm(df.iterrows()):
    if not CHANGE_FILES: 
        break
    shutil.copy2(join(base_dir, videos_folder_name, row['mapped_video_id']), join(base_dir, 'videos', f'{row["new_video_id"]}'))
# Out:
# 0it [00:00, ?it/s]

# %%
# Implement sanity check on extracted groud truth

gt_files = os.listdir(join(base_dir, 'groundTruth'))
selected_files = random.sample(gt_files, 5) # Randomly select 10 files

# Iterate over the selected files
for file in selected_files:
    print(f"Sanity check on gt file: {file}")
    
    # Read the file
    with open(join(base_dir, 'groundTruth', file), 'r') as f:
        lines = f.readlines()
        selected_lines = random.sample(list(enumerate(lines)), 10) # Randomly select 10 lines with line numbers
        
        # Print the selected lines with line numbers
        for line_number, line in selected_lines:
            print(f"Timestamp: {int((line_number + 1) / 30.0)}sec - {int((line_number + 1) / 30.0 // 60)}:{int((line_number + 1) / 30.0 % 60):02d}, class {line.strip()}")
    print()
# Out:
# Sanity check on gt file: case_133.txt
# Timestamp: 421sec - 7:01, class conjunctival_cautery
# Timestamp: 468sec - 7:48, class background
# Timestamp: 251sec - 4:11, class OVD_IOL_insertion
# Timestamp: 529sec - 8:49, class background
# Timestamp: 404sec - 6:44, class conjunctival_cautery
# Timestamp: 209sec - 3:29, class OVD_IOL_insertion
# Timestamp: 289sec - 4:49, class background
# Timestamp: 53sec - 0:53, class sideport
# Timestamp: 73sec - 1:13, class capsulorrhexis
# Timestamp: 516sec - 8:36, class background
#
# Sanity check on gt file: case_106.txt
# Timestamp: 133sec - 2:13, class incision
# Timestamp: 776sec - 12:56, class cortical_wash
# Timestamp: 630sec - 10:30, class background
# Timestamp: 144sec - 2:24, class incision
# Timestamp: 1020sec - 17:00, class OVD_IOL_insertion
# Timestamp: 505sec - 8:25, class background
# Timestamp: 509sec - 8:29, class hydroprocedure
# Timestamp: 1252sec - 20:52, class conjunctival_cautery
# Timestamp: 989sec - 16:29, class OVD_IOL_insertion
# Timestamp: 411sec - 6:51, class background
#
# Sanity check on gt file: case_151.txt
# Timestamp: 709sec - 11:49, class background
# Timestamp: 1526sec - 25:26, class tunnel_suture
# Timestamp: 968sec - 16:08, class cortical_wash
# Timestamp: 1724sec - 28:44, class tunnel_suture
# Timestamp: 2058sec - 34:18, class tunnel_suture
# Timestamp: 994sec - 16:34, class cortical_wash
# Timestamp: 2135sec - 35:35, class conjunctival_cautery
# Timestamp: 1174sec - 19:34, class OVD_wash
# Timestamp: 688sec - 11:28, class nucleus_prolapse
# Timestamp: 569sec - 9:29, class background
#
# Sanity check on gt file: case_131.txt
# Timestamp: 433sec - 7:13, class background
# Timestamp: 506sec - 8:26, class background
# Timestamp: 529sec - 8:49, class background
# Timestamp: 322sec - 5:22, class OVD_IOL_insertion
# Timestamp: 82sec - 1:22, class tunnel
# Timestamp: 144sec - 2:24, class background
# Timestamp: 199sec - 3:19, class hydroprocedure
# Timestamp: 195sec - 3:15, class hydroprocedure
# Timestamp: 163sec - 2:43, class capsulorrhexis
# Timestamp: 338sec - 5:38, class OVD_wash
#
# Sanity check on gt file: case_121.txt
# Timestamp: 1002sec - 16:42, class cortical_wash
# Timestamp: 1203sec - 20:03, class OVD_IOL_insertion
# Timestamp: 634sec - 10:34, class capsulorrhexis
# Timestamp: 598sec - 9:58, class capsulorrhexis
# Timestamp: 319sec - 5:19, class background
# Timestamp: 1451sec - 24:11, class conjunctival_cautery
# Timestamp: 1212sec - 20:12, class OVD_IOL_insertion
# Timestamp: 898sec - 14:58, class nucleus_prolapse
# Timestamp: 1284sec - 21:24, class background
# Timestamp: 13sec - 0:13, class background

# %%
# Incoperate additional remarks into ground truth files
remarks = pd.read_csv(join(base_dir, 'processed_remarks2.csv'))
remarks.head(50)

name_mapping = NameMapping(r'C:\Users\Simon\Data\2024_SICS_Phase\cleaned_annotations_v1.csv')

def parse_remark_cell(cell1, cell2, fps=30):
    cell_class = cell1.split(':')[0]
    cell_class = "_".join(cell_class.split('_')[:-1])
    #cell_class = mapping.get(cell_class)
    
    if mapping.get(cell_class) is None:
        #raise ValueError(f'Class {cell_class} not found in mapping')
        print(f'Class {cell_class} not found in mapping')
    
    start_time = ":".join(cell1.split(':')[1:])
    start_time = get_frame_from_time(start_time, fps=fps)
    
    end_time = ":".join(cell2.split(':')[1:])
    end_time = get_frame_from_time(end_time, fps=fps)
    
    return start_time, end_time, cell_class
    
    

for i, row in remarks.iterrows():
    print('Working on remarks for video: ', row.iloc[0])
    video_id = row.iloc[0]
    
    gt_file = name_mapping.get_gt_from_id(video_id)
    if not gt_file or not os.path.exists(join(base_dir, 'groundTruth', gt_file)):
        print(f'Ground truth file {gt_file} not found')
        continue
    gt_lines = open(join(base_dir, 'groundTruth', gt_file), 'r').readlines()
    
    for i in range(1, len(row), 2):
        if pd.isna(row.iloc[i]) or pd.isna(row.iloc[i+1]):
            continue
        start, end, cur_class = parse_remark_cell(row.iloc[i], row.iloc[i+1], fps=30)
        # print('Parsed remark: ', start, end, cur_class)
        
        for i in range(start, end):
            gt_lines[i] = cur_class + '\n'
    
    open(join(base_dir, 'groundTruth', gt_file), 'w').writelines(gt_lines)
# Out:
# Working on remarks for video:  Video 7
# Working on remarks for video:  Video 8
# Working on remarks for video:  Video 9
# Working on remarks for video:  Video 19
# Working on remarks for video:  Video 20
# Working on remarks for video:  Video 21
# Working on remarks for video:  Video 22
# Working on remarks for video:  Easy cataract 3
# Working on remarks for video:  video N18
# Working on remarks for video:  Video 17
# Working on remarks for video:  Video 15
# Working on remarks for video:  Video N29
# Working on remarks for video:  Video N39
# Working on remarks for video:  Video N40
# Working on remarks for video:  Video N42
# Working on remarks for video:  Video 58
# Working on remarks for video:  Video 68
# Working on remarks for video:  Video 12
# Working on remarks for video:  Video 13
# Working on remarks for video:  Video 5
# Working on remarks for video:  Video 9
# Working on remarks for video:  Video 8
# Working on remarks for video:  video n10
# Working on remarks for video:  video n11
# Working on remarks for video:  video n12
# Working on remarks for video:  video 52
# Working on remarks for video:  video 53
# Working on remarks for video:  video 54
# Working on remarks for video:  video 55
# Working on remarks for video:  nan
